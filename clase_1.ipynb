# %% [markdown]
# ![Clase aprendizaje no supervisado](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/taller-meca-aprendizaje%20no%20supervisado_banner%201169%20x%20200%20px%20-05.png)

# %% [markdown]
# El objetivo de este cuaderno es introducir el curso de Aprendizaje No Supervisado y el Análisis de Componentes principales que se estudiará en la primer semana del curo.
#
# **NO** es necesario editar el archivo o hacer una entrega. Los ejemplos contienen celdas con código ejecutable (`en gris`), que podrá modificar libremente. Esta puede ser una buena forma de aprender nuevas funcionalidades en el *cuaderno* o experimentar variaciones en los códigos de ejemplo.

# %% [markdown]
# ## Temas del Curso
#
# - Abarca cuatro grandes tópicos:
#
#     - Reducción de Dimensión (Semanas 1 y 2)
#
#     - Clustering (Semanas 3 y 4)
#
#     - Sistemas de Recomendación (Semanas 5 y 6)
#
#     - Análisis Geográfico (Semanas 7 y 8)

# %% [markdown]
# ## Profesor
#
# - Juan Camilo Prieto
#     * Economía
#     * Maestría en ingeniería de sistemas
#     * Consultor en el BID
#     * jc.prietoa@uniandes.edu.co

# %% [markdown]
# ## Actividades Quincenales
#
# - **Evaluación:**
#     -  Taller 1 - Reducción de Dimensión: 25%
#     -  Taller 2 - Clustering: 25%
#     -  Taller 3 - Sistemas de Recomendación: 25%
#     -  Taller 4 - Modelos geograficos: 25%

# %% [markdown]
# - Está permitido compartir código entre los compañeros de grupo para fines educativos y para facilitar la comprensión del problema a resolver, pero el análisis y las conclusiones deben ser propias.

# %% [markdown]
# ###  Equipos de trabajo
#
#
#   - Los equipos deben ser de dos personas.
#
#   - Los estudiantes son libres de conformarlos y decidir con quienes quieren trabajar.

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/datos.png)

# %% [markdown]
# ## ¿Hay diferentes tipos de datos?
#
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/tipos_datos.png)

# %% [markdown]
# ### Bases de datos no relacional
#
# * Los datos no se almacenan en tablas.
# * Se utilizan para almacenar datos no estructurados (texto, imagenes o videos).
# * Relativamente nuevo: No estandarizado.
# * Tiene problemas de rendimiento si necesito modificar/escribir la base frecuentemente.

# %% [markdown]
# ## Aprendizaje Supervisado vs **NO** Supervisado.
#
# - Estos modelos a diferencia de los vistos en aprendizaje supervisado no cuentan con una respuesta observada.

# %% [markdown]
# ### Aprendizaje Supervisado: Para cada predictor $x_i$ se observa una respuesta $y_i$.
#
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/supevised.png)

# %% [markdown]
# ### Aprendizaje **NO** Supervisado:
#
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/unsupevised.png)
#
#   - Complementa el curso de big data estudiando aplicaciones donde no hay una variable de respuesta definida.

# %% [markdown]
# # Introducción al Análisis de Componentes Principales

# %% [markdown]
# ## ¿Qué es?
#
# - Los grandes conjuntos de datos son cada vez más comunes y, a menudo, difíciles de interpretar.
#
# - Supongamos que tenemos una gran cantidad de variables observables $X_1,\dots,X_k$
#
# - ¿Necesitamos todas?
#
# - Si muchas son muy similares entre sí y están altamente correlacionados, tal vez la pregunta no es "¿cuál de ellas es importante?", sino más bien "¿cuál combinación lineal es importante?".
#
# - Por ejemplo, si tienes un conjunto de datos con una gran cantidad de calificaciones de exámenes tomados por estudiantes, y estás tratando de predecir algún resultado (calificaciones en clases futuras, éxito en la universidad, salarios futuros), lo que podría ser el mejor predictor es un promedio, o una combinación lineal, de las calificaciones de los exámenes.
#
# - PCA es una técnica de aprendizaje no supervisado que facilita esta tarea.
#
# - PCA reproyecta los datos a un nuevo espacio vectorial de forma tal que retengamos la máxima información posible.
#
# - Como se mide información? En PCA y en otros métodos estadísticos utilizamos la varianza.
#
# - Si algo varía más entonces tiene más información.
#
# - PCA identifica los ejes con la mayor cantidad de variación en los datos.

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_0.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_1.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_11.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_2.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_21.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_3.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_31.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot.png)

# %% [markdown]
# ![imagen](https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/figs/pca_best_projection_plot_C1C2.png)

# %% [markdown]
# - PCA "transforma" las variables originales en un nuevo conjunto de variables, los componentes principales, que no están correlacionados y que se ordenan de manera que los primeros retengan la mayor parte de la variación presente en todas las variables originales.
#
# - PCA se refiere entonces al proceso por el cual los componentes principales son calculados, y el uso de estos componentes para entender los datos.
#
# ## Como lo hace?
#
# - Reproyectando a través de combinaciones lineales
#
# - Por ejemplo, si tenemos 7 variables ($X_1, X_2, \dots, X_{7} $), el primer componente principal va a buscar la combinación lineal de estas 7 variables de forma tal que la información retenida sea la más alta posible
#
#
# \begin{align}
# PC_1 = \delta_{1,1} X_1+ \delta_{2,1} X_2 + \dots + \delta_{7,1} X_{7}
# \end{align}
#
#
# en donde $\delta_1$ es un vector de $7$ números reales $(\delta_1= \delta_{1,1},\dots, \delta_{7,1})$, que llamamos pesos o loadings y han sido normalizados para que $\sum_{j=1}^{7} \delta_{j1}^2=1$
#
#
# - Podemos entonces calcular los componentes principales restantes, agregando la restricción de que este no este correlacionado con PC1.

# %% [markdown]
# ## PCA como analisis de factores
#
#
# ### Modelo de Factor Único
#
# $$x_i = h f_i + u_i$$
#
# - h y $u_i$ son $k \times 1$
# - $f_i$ es el factor que es $1 \times 1$
# - $h$ son los loadings (cargas, pesos) factoriales.
# - $u_i$ son los errores idiosincráticos.
#
# En este modelo, el factor $f_i$ afecta a todos los regresores $x_{ji}$.
# - Pero la magnitud es específica para el regresor y se captura por $h$.
#
# ### Escalado
#
# - La escala de $h$ y $f_i$ no se identifican por separado, ni su signo.
# - Por esto reescalamos $h^T h = 1$.
#
# #### Ejemplo de calificaciones en exámenes
#
# - $x_i$ es un conjunto de calificaciones en exámenes para un estudiante dado.
# - $f_i$ es la habilidad latente del estudiante.
# - $h$ es cómo la habilidad afecta las diferentes calificaciones en exámenes.
#
# - Algunos exámenes pueden estar altamente relacionadas con la habilidad.
# - Algunos exámenes pueden estar menos relacionadas.
# - Algunos exámenes no estar relacionadas (¿aleatorias?).

# %% [markdown]
# ### Modelo de Factores Múltiples
#
# $$x_i = \sum_{m=1}^{r} h_m f_{mi} + u_i = H_0 f_i + u_i$$
#
# - Los loadings normalizadas para ser ortonormales $\rightarrow$ factores no correlacionados
#
# - Las cargas factoriales $h_m$ son los eigen vectors de $\Sigma_x$ (varianza de x) asociados con los mayores $r$ eigen values.
#
#
# #### Ejemplo de calificaciones en exámenes (cont.)
#
# - Existen más de una forma de "habilidad". Ej. literaria y matemática.
# - En la economía laboral, se ha hipotetizado una distinción entre habilidad cognitiva y no cognitiva que ha sido muy útil para explicar los patrones salariales (algunos trabajos requieren una u otra, y algunos ambas, por ejemplo, cirujano).

# %% [markdown]
# ### A los datos

# %%
# Cargamos las librerías a utilizar
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb
np.set_printoptions(precision=2)

# %% [markdown]
# Datos del artículo "Peer Effects, Teacher Incentives, and the Impact of Tracking: Evidence from a Randomized Evaluation in Kenya" de Duflo, Dupas y Kremer (AER, 2011)

# %%
# Cargamos los datos

X = pd.read_excel('https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/data/duflo_data.xlsx', index_col=0)
X.head()
# Out:
#          wordscore  sentscore  letterscore  spellscore  additions_score  \
# pupilid
# 4301003          0          6            0           0                1
# 4301004          0          1            1           0                0
# 4301005          0          0           10           0                4
# 4301007          0          0            7           0                2
# 4301009          0          0           14           0                3
#
#          substractions_score  multiplications_score
# pupilid
# 4301003                    1                      0
# 4301004                    0                      0
# 4301005                    5                      0
# 4301007                    4                      0
# 4301009                    1                      0

# %% [markdown]
# Variables:
#
# - `pupilid`: ID del estudiante
# - `wordscore`: Calificación final en la sección de Reconocimiento de Palabras (máximo: 24)
# - `sentscore`: Calificación final en la sección de Reconocimiento de Oraciones (máximo: 40)
# - `letterscore`: Calificación final en la sección de Reconocimiento de Letras (máximo: 70)
# - `spellscore`: Calificación final en la sección de Ortografía (máximo: 10)
# - `additions_score`: Calificación final en la sección de Adiciones
# - `substractionscore`: Calificación final en la sección de Sustracciones
# - `multiplicationscore`: Calificación final en la sección de Multiplicaciones

# %%
#dimensión
X.shape
# Out:
# (5790, 7)

# %%
X.describe()
# Out:
#          wordscore    sentscore  letterscore   spellscore  additions_score  \
# count  5790.000000  5790.000000  5790.000000  5790.000000      5790.000000
# mean      5.841451     4.291537    22.207427     2.240587         3.660794
# std       7.778241     6.560979    19.520402     3.094634         2.177548
# min       0.000000     0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     6.000000     0.000000         2.000000
# 50%       2.000000     2.000000    18.000000     0.000000         4.000000
# 75%      10.000000     6.000000    35.000000     4.000000         5.000000
# max      24.000000    38.000000    70.000000    10.000000         9.000000
#
#        substractions_score  multiplications_score
# count          5790.000000            5790.000000
# mean              3.133851               0.763212
# std               2.066826               1.137192
# min               0.000000               0.000000
# ...

# %%
X.corr()
# Out:
#                        wordscore  sentscore  letterscore  spellscore  \
# wordscore               1.000000   0.551071     0.623029    0.798314
# sentscore               0.551071   1.000000     0.454619    0.547945
# letterscore             0.623029   0.454619     1.000000    0.708103
# spellscore              0.798314   0.547945     0.708103    1.000000
# additions_score         0.488700   0.321686     0.531918    0.521566
# substractions_score     0.408571   0.256443     0.476502    0.448689
# multiplications_score   0.413130   0.282752     0.428541    0.450696
#
#                        additions_score  substractions_score  \
# wordscore                     0.488700             0.408571
# sentscore                     0.321686             0.256443
# letterscore                   0.531918             0.476502
# spellscore                    0.521566             0.448689
# additions_score               1.000000             0.703917
# ...

# %%
plt.figure(figsize=(20,20))

dataplot = sb.heatmap(X.corr(), cmap="YlGnBu", annot=True)

plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_std=True, with_mean=True)
X_scaled = scaler.fit_transform(X)


pcaX = PCA()

pcaX.fit(X_scaled)
# Out:
# PCA()

# %%
pd.DataFrame(pcaX.components_)
# Out:
#           0         1         2         3         4         5         6
# 0  0.410430  0.315996  0.404010  0.429485  0.384807  0.354831  0.331710
# 1 -0.322151 -0.494069 -0.126452 -0.276761  0.407876  0.515354  0.357177
# 2 -0.082828  0.325405 -0.275979 -0.114717 -0.241649 -0.248474  0.823282
# 3 -0.220334  0.719870 -0.327697 -0.281344  0.257532  0.314729 -0.285172
# 4 -0.564067  0.178482  0.766587 -0.208017 -0.119204 -0.046562  0.051653
# 5 -0.058014 -0.007690  0.014227 -0.068974  0.738960 -0.667453  0.007816
# 6 -0.592302  0.005174 -0.222211  0.773694  0.023940 -0.007037 -0.023414

# %%
pd.DataFrame(pcaX.explained_variance_ratio_*100)
# Out:
#            0
# 0  57.403541
# 1  14.930680
# 2   8.023694
# 3   7.505991
# 4   5.321225
# 5   4.135443
# 6   2.679426

# %%
# Descargar libreria
# !pip install pca

# %%
# Carguemos el paquete
from pca import pca

model_estudiantes = pca(n_components=2,normalize=True, verbose=0)
results_estudiantes = model_estudiantes.fit_transform(X)

# %%
# Biplot
model_estudiantes.biplot(PC=[0, 1], alpha=0.1,legend=False, color_arrow="red", arrowdict={'color_text':"black"})
# Out:
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '2 Principal Components explain [72.33%] of the variance'}, xlabel='PC1 (57.4% expl.var)', ylabel='PC2 (14.9% expl.var)'>)

# %%
scores = results_estudiantes['PC']
scores
# Out:
#                PC1       PC2
# 4301003  -2.055870 -0.812724
# 4301004  -2.624432 -0.879343
# 4301005  -0.920917  1.133802
# 4301007  -1.508169  0.529218
# 4301009  -1.701631 -0.076908
# ...            ...       ...
# 10201051  3.148243  0.559085
# 10201052  2.820152 -0.465774
# 10201053  2.234405  0.162240
# 10201054  3.072256  0.783202
# 10201055  5.421204 -1.991367
#
# [5790 rows x 2 columns]

# %%
sorted_scores_pc1 = scores.sort_values(by='PC1', ascending=False)
sorted_scores_pc1
# Out:
#               PC1       PC2
# 7081041  7.202670 -0.405561
# 7081073  7.037468 -1.353126
# 5001075  6.651543  1.812867
# 7081055  6.538757 -1.626120
# 7081005  6.398587 -0.646140
# ...           ...       ...
# 4851062 -2.693297 -0.797554
# 4831108 -2.693297 -0.797554
# 4851023 -2.693297 -0.797554
# 4361008 -2.693297 -0.797554
# 9781100 -2.693297 -0.797554
#
# [5790 rows x 2 columns]

# %%
# Graficamos la estimación de densidad de las puntuaciones ordenadas para PC1
plt.figure(figsize=(10, 6))
sb.kdeplot(sorted_scores_pc1['PC1'], fill=True)
plt.title('Density Estimation of Sorted Scores for PC1')
plt.xlabel('PC1 Scores')
plt.ylabel('Density')
plt.show()

# %%
# Incluye la deteccion de outliers
model_estudiantes.scatter(density=True, alpha=0.01)
# Out:
# [scatterd] >INFO> Add density layer
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.
# [scatterd] >INFO> Create scatterplot
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '2 Principal Components explain [72.33%] of the variance'}, xlabel='PC1 (57.4% expl.var)', ylabel='PC2 (14.9% expl.var)'>)

# %% [markdown]
# #### Ejemplo cálculo primer componente
#
# Ilustremos en detalle el cálculo del primer componente principal en `Python` utilizando los datos mencionados anteriormente de la
# [Encuesta Nacional de Presupuestos de los Hogares (ENPH) de Colombia](https://www.dane.gov.co/index.php/estadisticas-por-tema/pobreza-y-condiciones-de-vida/encuesta-nacional-de-presupuestos-de-los-hogares-enph), realizada por el DANE en 2017. El archivo `gasto_col_2017_norm_all.csv` disponible en la carpeta `data`, contiene los gastos individuales promedios estandarizados en las 12 divisiones que releva el DANE para 38 ciudades colombianas.

# %%
#Cargamos las librerías a utilizar
import numpy as np
import pandas as pd


# Cargamos y visualizamos la primeras observaciones de los datos

gasto = pd.read_csv('https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/data/gasto_col_2017_norm_all.csv')
gasto = gasto.set_index("Ciudad")
gasto.head()
# Out:
#                  Alimentos y bebidas no alcohólicas  \
# Ciudad
# Arauca                                    -0.893243
# Armenia                                    1.411143
# Barrancabermeja                           -1.145930
# Barranquilla                              -0.183745
# Bogotá                                     1.355724
#
#                  Bebidas alcohólicas y tabaco  Prendas de vestir y calzado  \
# Ciudad
# Arauca                              -1.491704                    -1.212847
# Armenia                             -0.317263                     1.339782
# Barrancabermeja                      0.551373                    -0.644432
# Barranquilla                        -0.774835                    -0.837466
# Bogotá                               0.255023                     1.774131
#
#                  Alojamiento, agua, electricidad, gas y otros combustibles  \
# Ciudad
# Arauca                                                   -0.187501
# ...

# %% [markdown]
# La matriz de varianzas es:

# %%
S = gasto.cov()
S
# Out:
#                                                     Alimentos y bebidas no alcohólicas  \
# Alimentos y bebidas no alcohólicas                                            1.000000
# Bebidas alcohólicas y tabaco                                                 -0.109692
# Prendas de vestir y calzado                                                   0.495619
# Alojamiento, agua, electricidad, gas y otros co...                            0.582737
# Muebles, artículos para el hogar y para la cons...                            0.495742
# Salud                                                                         0.471145
# Transporte                                                                    0.608363
# Información y comunicación                                                    0.571717
# Recreación y cultura                                                          0.573661
# Educación                                                                     0.312434
# ...

# %% [markdown]
# Los valores propios son las raíces de la ecuación:
#
# $$|S-\lambda I| =0 $$
#
# y los obtenemos en `Python` con:

# %%
eig_val, eig_vec = np.linalg.eig(S)
eig_val
# Out:
# array([8.04, 1.25, 0.69, 0.57, 0.47, 0.32, 0.29, 0.03, 0.05, 0.11, 0.1 ,
#        0.08])

# %% [markdown]
# El máximo eigenvalor es el primero y el eigenvector  asociado a este eigenvalor nos dará los pesos o *loadings* del primer componente principal:

# %%
eig_vec=eig_vec.T
eig_vec[[0]].round(2)
# Out:
# array([[0.23, 0.07, 0.29, 0.31, 0.32, 0.3 , 0.3 , 0.33, 0.32, 0.28, 0.28,
#         0.33]])

# %% [markdown]
# Por lo tanto, el primer componente principal es:
#
# \begin{align}
# f_1 =  0.23 \times \text{Alimentos y bebidas no alcohólicas} + 0.07 \times \text{Bebidas alcohólicas y tabaco} + \dots + 0.33 \times \text{Bienes y servicios diversos}
# \end{align}
#
# Calculando este componente para cada una de las ciudades tenemos entonces un índice que reduce las tres variables en una:

# %%
f1=gasto.dot(eig_vec[[0]].T) #calculamos f1
f1.columns = ['CP1'] #nombramos la columna del primer componente como CP1
f1.head()
# Out:
#                       CP1
# Ciudad
# Arauca          -2.465760
# Armenia          3.062761
# Barrancabermeja -0.687593
# Barranquilla    -0.359423
# Bogotá           8.604254

# %% [markdown]
# Si ordenamos las ciudades según esta nueva variable construida (PCA), se puede notar que las ciudades quedan prácticamente ordenadas por su ingreso. El primer componente principal entonces esta proyectando sobre una medida relacionada al poder de gasto de las ciudades.

# %%
f1.sort_values(by='CP1', ascending=False).head()
# Out:
#                          CP1
# Ciudad
# Bogotá              8.604254
# Medellín y A.M.     4.429535
# Manizales y A.M.    4.134911
# Tunja               3.806251
# Bucaramanga y A.M.  3.747163

# %% [markdown]
# ### Cálculo del segundo componente principal
#
# Luego de calcular el primer componente principal $f_1$, podemos encontrar también el segundo componente principal, $f_2$:
#
# \begin{align}
# f_2 &= X \delta'_2 \\
#     &= \delta_{21} X_1+ \delta_{22} X_2 + \dots + \delta_{2k} X_k
# \end{align}
#
# El segundo componente principal, será la combinación lineal que tiene la máxima varianza de todas las combinaciones lineales ortogonales a $f_1$. En otras palabras, responde a la pregunta: ¿Cuál es la mejor combinación lineal de las variables $X_1,X_2,\dots,X_k$ no correlacionada al primer componente principal? Intuitivamente, esta es la "segunda mejor" combinación lineal de $X_1,X_2,\dots,X_k$, que no esta contenida en el primer componente.
#
#
#
# El cálculo del segundo componente entonces responde al siguiente problema:
#
# \begin{align}
# \underset{\delta_2}{max}\,\, \delta_2 S \delta'_2 \\
# \text{sujeto a}   \\
# \delta_2 \delta'_2 &= 1
# y \\
# \delta_2 \delta'_1 &=0 \\ \nonumber
# \end{align}
#
#
# Donde el objetivo a maximizar y la primera restricción son similares al del problema del primer componente. La diferencia surge en la segunda restricción donde imponemos que $\delta_1 \delta'_2  =0$ lo que asegura que los componentes no estén correlacionados (que sean ortogonales). Escribiendo el Lagrangiano,
#
# \begin{align}
# \mathcal{L} = \delta_2 S \delta'_2 + \lambda_2 (1-\delta_2\delta'_2 + \lambda_{21} (0-\delta_1 \delta'_2)
# \end{align}
#
# y maximizaremos esta expresión de la forma habitual derivando respecto a $\delta_2$ e igualando a cero:
#
# \begin{align}
# \frac{\partial \mathcal{L}}{\partial \delta_2}= -2 S \delta'_2 - \lambda_2 2 \delta'_2 - \lambda_{21}\delta'_1=0
# \end{align}
#
# Pre multiplicando por $\delta_1$
#
#
# \begin{align}
#      -2 \delta_1 S \delta'_2 - \lambda_2 2 \delta_1 \delta'_2 - \lambda_{21}\delta_1 \delta'_1 = 0
# \end{align}
#
# Notemos que $\delta_1 \delta'_1 =1$ por lo tanto $\lambda_{21}=0$, y que $\delta_1 \delta'_2 =0$. Usando estas  ecuaciones tenemos:
#
#
# \begin{align}
#  S \delta'_2 &= \lambda_2 \delta'_2 \\
# \delta_2  S \delta'_2 &= \lambda_2
# \end{align}
#
#
# De forma que $\delta_2$ es un eigenvector de $S$, y puesto que queremos maximizar la varianza, deberíamos elegir el eigenvector asociado al eigenvalue mas grande, pero este ya lo utilizamos para el primer componente. Entonces $\delta_2$  es el eigenvector asociado al segundo eigenvalue mas grande.
#
#
#
# Siguiendo esta lógica, por inducción es posible seguir calculando componentes cada uno ortogonal entre si y decrecientes en importancia. En general, para una matriz $X$ con  $n$ observaciones y $k$ variables tiene al menos el mínimo entre el número de observaciones menos 1 $(n-1)$ y el número de variables $(k)$, i.e.  $min(n-1,k)$, componentes principales distintos.

# %% [markdown]
# #### Ejemplo cálculo PCA (cont.)
#
# Continuando con el ejemplo anterior, el segundo componente principal es aquel que esta asociado al segundo eigenvalue mayor, que es 1.24.

# %%
eig_val
# Out:
# array([8.04, 1.25, 0.69, 0.57, 0.47, 0.32, 0.29, 0.03, 0.05, 0.11, 0.1 ,
#        0.08])

# %% [markdown]
# El eigenvector asociado a este eigenvalue:

# %%
eig_vec[[1]]
# Out:
# array([[ 0.41, -0.81, -0.09,  0.09, -0.04, -0.07,  0.19,  0.1 ,  0.03,
#         -0.32, -0.05,  0.01]])

# %% [markdown]
# El segundo componente principal es:
#
# \begin{align}
# f_2 =  -0.46 \times \text{Alimentos y bebidas no alcohólicas} + (-0.35) \times \text{Bebidas alcohólicas y tabaco} + \dots + 0.31 \times \text{Bienes y servicios diversos}
# \end{align}
#
# Calculando este para cada una de las ciudades tenemos entonces un índice que reduce las tres variables en una:

# %%
f2=gasto.dot(eig_vec[[1]].T) #calculamos f2
f2.columns = ['CP2'] #nombramos la columna del primer componente como CP2
f2.sort_values(by='CP2', ascending=False).head()
# Out:
#                          CP2
# Ciudad
# Rionegro            1.590442
# Mitú                1.317832
# Bucaramanga y A.M.  1.064920
# Pereira y A.M.      1.028697
# Arauca              0.995292

# %% [markdown]
# ## Cálculo de componentes principales con el paquete  `PCA`
#
#
# Ahora, vamos a realizar el cálculo de los componentes pricipales utilizando el paquete [pca](https://pypi.org/project/pca/) disponible en `PyPI`. Esta biblioteca es una herramienta de análisis de componentes principales que proporciona una interfaz fácil de usar y expande las capacidades que tiene la clase  [PCA](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)  de la librería [scikit-learn](https://scikit-learn.org/stable/)
#
#
#
# Entonces iniciemos importando la librería:

# %%
# Carguemos el paquete
from pca import pca

# %% [markdown]
# Con el paquete [pca](https://pypi.org/project/pca/)  importado, el siguiente paso es inicializar un objeto PCA. La biblioteca `pca` proporciona una clase `pca` que podemos utilizar para este propósito. Una vez que tengamos nuestro objeto PCA, podemos ajustarlo a nuestros datos.
#
# A diferencia de la biblioteca scikit-learn](https://scikit-learn.org/stable/)
# , el paquete [pca](https://pypi.org/project/pca/)  combina los pasos de ajuste y transformación en una sola función, lo que simplifica el proceso. Además, este paquete proporciona visualizaciones integradas que nos permiten ver fácilmente los resultados del PCA.
#
# Vamos a inicializar nuestro objeto PCA y ajustarlo a nuestros datos.

# %%
# Inicializamos el objeto PCA
model = pca(n_components=2)

# %%
# Ajustamos el PCA a nuestros datos
gasto_pca = model.fit_transform(gasto, verbose=False)

# %% [markdown]
# El método nos retorna un diccionario con multiples componentes. Por ahora nos interesan particularmente los *loadings*

# %%
gasto_pca['loadings']
# Out:
#      Alimentos y bebidas no alcohólicas  Bebidas alcohólicas y tabaco  \
# PC1                            0.229523                      0.075000
# PC2                           -0.414372                      0.807338
#
#      Prendas de vestir y calzado  \
# PC1                     0.290238
# PC2                     0.092143
#
#      Alojamiento, agua, electricidad, gas y otros combustibles  \
# PC1                                           0.307090
# PC2                                          -0.086983
#
#      Muebles, artículos para el hogar y para la conservación ordinaria del hogar  \
# PC1                                           0.322190
# PC2                                           0.040411
#
#         Salud  Transporte  Información y comunicación  Recreación y cultura  \
# PC1  0.299419    0.304631                    0.328533              0.324178
# PC2  0.073355   -0.185569                   -0.101016             -0.032148
#
# ...

# %% [markdown]
# Y los componentes principales.

# %%
gasto_pca['PC']
# Out:
#                             PC1       PC2
# Arauca                -2.465760 -0.995292
# Armenia                3.062761 -0.746234
# Barrancabermeja       -0.687593  0.992482
# Barranquilla          -0.359423 -0.622977
# Bogotá                 8.604254  0.456917
# Bucaramanga y A.M.     3.747163 -1.064920
# Buenaventura          -2.177006  0.124911
# Cali                   3.356678  0.302655
# Cartagena             -0.401153  0.012728
# Cúcuta y A.M.         -0.939191 -0.925839
# Florencia             -2.444097 -0.077411
# Ibagué                 0.728506 -0.886609
# Inírida               -2.296187  3.840714
# Leticia               -2.910621 -0.294022
# Manizales y A.M.       4.134911 -0.174609
# Medellín y A.M.        4.429535 -0.304620
# Mitú                  -3.876915 -1.317832
# Mocoa                 -1.346317  2.011299
# Montería              -1.916648  0.370743
# Neiva                  1.365610 -0.054708
# Pasto                  1.281469 -0.667128
# ...

# %% [markdown]
#  Notemos que son numericamente iguales a los encontrados anteriormente, aunque no necesariamente coincide el signo (estudiaremos por qué sucede esto en el próximo cuaderno).
#
# La biblioteca `pca` proporciona varias funcionalidades extras. Entre ellas la función `biplot` que nos permite visualizar fácilmente los componentes principales y los *loadings* en un sólo gráfico.  Este tipo de gráfico nos muestra tanto las puntuaciones de las observaciones (en este caso, las ciudades) como los vectores de carga de las variables (características de los gastos) en el mismo espacio de representación. Esto es útil porque te permite ver la relación entre las observaciones, cómo se relacionan con las dimensiones del PCA, y cómo las variables contribuyen a estas dimensiones.
#
# Creemos un biplot de nuestros resultados:

# %%
import matplotlib

# Creamos el biplot
fig, ax = model.biplot(legend=False, color_arrow="red", arrowdict={'color_text':"black"})
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca] >Plot PC1 vs PC2 with loadings.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.

# %% [markdown]
# - **Representación del biplot:** Ilustra los dos primeros componentes principales:
#   - **PC1 (eje x)**
#   - **PC2 (eje y)**
#
# - **Interpretación de las flechas:**
#   - Representan los *loadings* de las variables en los componentes.
#   - La **dirección** indica la relación con los componentes principales.
#   - La **longitud** muestra la magnitud de la contribución de cada variable.
#
# - **Puntos en el biplot:**
#   - Cada punto representa una **ciudad**.
#   - La **cercanía entre puntos** indica similitudes en los perfiles de gasto.
#   - La **posición relativa** respecto a los ejes muestra cómo influyen los componentes en las ciudades.
#
# - **Correlaciones entre variables:**
#   - Flechas que apuntan en la **misma dirección** → correlación positiva.
#   - Flechas más largas → mayor influencia en los componentes principales.
#   - Ejemplos de *loadings*:
#     - **Bebidas alcohólicas y tabaco:** *loading* de **0.807338** en PC2.
#     - **Prendas de vestir y calzado:** *loading* de **0.290238** en PC1.
#
# - **Importancia del biplot:**
#   - Permite **interpretar un PCA** visualmente.
#   - Muestra tanto la información de **observaciones** como de **variables** en un solo gráfico.
#   - Facilita la comprensión de la **estructura subyacente de los datos**.
#
# - **Limitaciones del biplot:**
#   - Puede ser complejo de interpretar con **datos de alta dimensionalidad**.
#   - Aun así, es una **herramienta valiosa** para la exploración inicial y la visualización de patrones.

# %% [markdown]
# ## Escalar las variables
#
# En los ejemplos anteriores utilizamos datos que estaban estandarizados, es decir, centrados para tener media cero y escalados para tener varianza uno.  Desde un punto estrictamente matemático no hay nada intrínsecamente incorrecto en hacer combinaciones lineales de variables con diferentes unidades de medida. Sin embargo, cuando usamos PCA buscamos maximizar varianza y la varianza se ve afectada por las unidades de medida. Esto implica que los componentes principales basados en la matriz de covarianza $S$ van a cambiar si las unidades de medida de una o más variables cambian. Para que esto no suceda, es práctica habitual  estandarizar las variables. Es decir, cada valor de la matriz de datos $X$ es centrado y dividido por la desviación estándar:
#
# \begin{align}
# z_{ij} = \frac{x_{ij}-\bar{x_j}}{s_j}
# \end{align}
#
# donde $\bar{x_j}$ es la media y ${s_j}$ es el desvío estándar de la columna $j$. Entonces, la matriz de datos iniciales $X$ es remplazada por la matriz de datos estandarizados $Z$.
#
# Al estandarizar la matriz de datos, la matriz de covarianza $S$ es simplemente la matriz de correlación de los datos originales, lo que en la literatura se lo conoce como la matriz de correlación de PCA.
#
# Esto contrasta con otras técnicas de aprendizaje supervisado como la regresión lineal, donde escalar las variables no tiene ningún efecto. Si multiplicamos una variable por $\frac{1}{\alpha}$, los coeficientes estarán multiplicados por $\alpha$, no teniendo un efecto en el modelo obtenido.
#
# Para ilustrar cómo se estandariza en `Python`, vamos a utilizar los datos de la  Encuesta Nacional de Presupuestos de los Hogares (ENPH) de Colombia, realizada por el DANE en 2017. Los datos contienen información sobre el gastos promedio en distintos rubros para 38 ciudades colombianas.

# %%
#Cargamos las librerias a utilizar
import pandas as pd
import numpy as np

# Cargamos y visualizamos la primeras observaciones de los datos
X = pd.read_csv('https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/data/gasto_col_2017.csv')
X = X.set_index("Ciudad")
X.head()
# Out:
#                  Alimentos y bebidas no alcohólicas  \
# Ciudad
# Arauca                                    76.532496
# Armenia                                  104.227192
# Barrancabermeja                           73.495641
# Barranquilla                              85.059421
# Bogotá                                   103.561150
#
#                  Bebidas alcohólicas y tabaco  Prendas de vestir y calzado  \
# Ciudad
# Arauca                              11.983778                    21.065229
# Armenia                             18.610392                    39.651621
# Barrancabermeja                     23.511551                    25.204020
# Barranquilla                        16.028608                    23.798484
# Bogotá                              21.839434                    42.814236
#
#                  Alojamiento, agua, electricidad, gas y otros combustibles  \
# Ciudad
# Arauca                                                  158.952746
# ...

# %%
# Estandarizamos los datos
mu = X.mean()
sigma = X.std()
Z = (X - mu)/sigma
Z.head()
# Out:
#                  Alimentos y bebidas no alcohólicas  \
# Ciudad
# Arauca                                    -0.893243
# Armenia                                    1.411143
# Barrancabermeja                           -1.145930
# Barranquilla                              -0.183745
# Bogotá                                     1.355724
#
#                  Bebidas alcohólicas y tabaco  Prendas de vestir y calzado  \
# Ciudad
# Arauca                              -1.491704                    -1.212847
# Armenia                             -0.317263                     1.339782
# Barrancabermeja                      0.551373                    -0.644432
# Barranquilla                        -0.774835                    -0.837466
# Bogotá                               0.255023                     1.774131
#
#                  Alojamiento, agua, electricidad, gas y otros combustibles  \
# Ciudad
# Arauca                                                   -0.187501
# ...

# %% [markdown]
# **Diferencia con los resultados con la data normalizada?**

# %% [markdown]
# ## Descomposición espectral o eigendecomposición
#
# La descomposición espectral, también conocida como eigendecomposición, es un componente crucial en el análisis de componentes principales (PCA). Esta técnica de descomposición de matrices permite identificar los valores propios y los vectores propios de la matriz de covarianza de los datos, elementos esenciales para comprender la distribución de la varianza en conjuntos de datos multidimensionales. Descomponer una matriz en este contexto implica hallar un producto de matrices que reproduzca la matriz original. En la eigendecomposición, esto se logra descomponiendo la matriz en el producto de sus eigenvectores y eigenvalores. Los eigenvectores delinean las direcciones de máxima varianza en los datos, mientras que los eigenvalores señalan la magnitud de esta varianza.
#
# Veamos cómo se usan los eigenvectores y eigenvalores para descomponer una matriz. Tomando los eigenvectores de una matriz $A_{m\times m}$ podemos concatenarlos y colocarlos en una matriz $P$. Entonces $P$ será una matriz cuyas columnas son los eigenvectores de $A$:
#
# \begin{align}
# A= P\Lambda P'
# \end{align}
#
# donde $\Lambda =diag(\lambda)$ es una matriz diagonal de los eigenvalores.
#
# Es importante mencionar que esta descomposición es aplicable únicamente a matrices cuadradas, como lo es la matriz de covarianza, lo que limita su uso a este tipo de matrices.
#
# Para ilustrar en `Python` la descomposición usaremos una versión abreviada de 3 variables del ejemplo del *cuaderno* de *Fundamentos Teóricos*:

# %%
gasto = pd.read_csv('https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/data/gasto_col_2017_norm.csv')
gasto = gasto.set_index("Ciudad")
S = gasto.cov()
S
# Out:
#                Salud  Transporte  Educación
# Salud       1.000000    0.687662   0.644640
# Transporte  0.687662    1.000000   0.541518
# Educación   0.644640    0.541518   1.000000

# %% [markdown]
# Notemos que la matriz S es una matriz cuadrada:

# %%
S.shape
# Out:
# (3, 3)

# %% [markdown]
# obtenemos los eigenvalues y los eigenvectores:

# %%
eig_val, eig_vec = np.linalg.eig(S)
eig_val
# Out:
# array([2.25, 0.29, 0.46])

# %% [markdown]
# creamos la matriz $\Lambda =diag(\lambda)$:

# %%
eig_val_diag = np.diag(eig_val)
eig_val
# Out:
# array([2.25, 0.29, 0.46])

# %% [markdown]
# y reconstrumios $S$:

# %%
eig_vec.dot(eig_val_diag).dot(eig_vec.T)
# Out:
# array([[1.  , 0.69, 0.64],
#        [0.69, 1.  , 0.54],
#        [0.64, 0.54, 1.  ]])

# %% [markdown]
# Recobrando de esta forma la matriz $S$ original.

# %% [markdown]
# ## Proporción de Varianza Explicada
#
#
# Una propiedad muy útil del procedimiento del cálculo de componentes principales es que la variabilidad total de $X$ es la suma de los $k$ eigenvalores de $V(X)=S$. Para demostrarlo supongamos que $\lambda_1,\dots,\lambda_k$ son los eigenvalores de $V(X)=S$, ordenados de mayor a menor, y que $p_1 , \dots , p_K$ son los eigenvectores correspondientes. Adicionalmente llamemos $P$ a la matriz cuyas columnas son estos eigenvectores.
#
# Supongamos también que $f_j= X \delta'_j$ es el $j-ésimo$ componente principal, entonces
#
# \begin{align}
# V (f_j ) &= \delta_j S \delta'_j  \\\
#          &= p_j P\Lambda P' p'_j  \\\
#          &= \lambda_j
# \end{align}
#
# Donde la segunda igualdad se desprende de la descomposición espectral.
#
# Este resultado nos dices que la varianza del $j-ésimo$ componente principal es el $j-ésimo$ eigenvalor ordenado de S.
#
# Usando este resultado podemos ver que la varianza total de $X$ va a ser la suma de las varianza de las variables $x_j$:
#
# \begin{align}
# tr(\Sigma) = tr(P \Lambda P')= tr(PP' \Lambda ) = \sum_{j=1}^k \lambda_j= \sum_{j=1}^k V(f_j)
# \end{align}
#
#
# Este resultado nos permite preguntarnos: ¿Cuánta información perdimos por proyectar los datos en unos cuantos componentes principales? Esto es, ¿cuánto de la varianza esta contenida en los primeros componentes principales? Usando la ecuación anterior podemos ver la proporción de varianza contenida en cada componente principal:
#
# \begin{align}
# \frac{\lambda_k}{\sum_{j=1}^k \lambda_j}
# \end{align}
#
# Continuando con el ejemplo, podemos calcular la proporción de varianza contenida en cada componente principal:

# %%
np.sort(eig_val)[::-1]/sum(eig_val)
# Out:
# array([0.75, 0.15, 0.1 ])

# %% [markdown]
# Asi podemos ver en este ejemplo:
#
# - El primer componente principal explica el 75% del total de la varianza.
#
# - El segundo componente principal explica el 15.4% del total de la varianza.
#
# - El tercer componente principal explica el 9.6% del total de la varianza.
#
# Finalmente notemos que la suma da 100%. Lo invito a replicar y comparar estos resultados con los datos que utilizados para la ilustración de la estandarización al inicio de este *cuaderno*.

# %% [markdown]
# ## ¿Cuántos componentes principales debemos seleccionar?
#
#
# En el *cuaderno* de *Fundamentos Teóricos* mencionamos que una matriz $X$ de dimensión $n \times k$ tiene en general  $min(n-1,k)$ componentes principales distintos.  En la práctica generalmente no estamos interesados en todos los componentes, sino más bien quedarnos con los primeros que nos permitan visualizar o interpretar datos. En efecto, nos gustaría quedarnos con el mínimo numero que nos permita una buena comprensión de los datos. Por ejemplo, en el ejemplo anterior los dos primeros componentes explican mas del 90% del total de la varianza. Es decir, en este caso, con dos componentes logramos una buena representación de los datos.
#
# La pregunta natural que surge aquí es si hay una forma establecida para determinar el número de componentes principales a utilizar. Desafortunadamente, no existe una forma objetiva aceptada en la literatura de responderla. Sin embargo, hay tres enfoques simples que pueden servir de guía para decidir el número de componentes principales relevantes.
#
# Estos son:
#
# - Examen visual de un gráfico de sedimentación (scree plot).
# - Proporción de varianza explicada.
# - Criterio de Kaiser.

# %% [markdown]
# ### Examen visual de un gráfico de sedimentación (scree plot)
#
# Un enfoque ampliamente utilizado consiste en elegir el número de componentes principales examinando un diagrama de sedimentación o scree plot por su nombre en inglés. La gráfica de abajo muestra un scree plot, en el cual el panel A resume la proporción de varianza explicada por cada componente principal, y el panel B como suma acumulada.
#
# ![](figs/plot_S1_LSC2_1.png)

# %% [markdown]
# - **Identificación del "codo" en la gráfica:** Se busca un punto donde la **proporción de varianza explicada** por cada componente principal disminuye abruptamente.
# - **Concepto de "sedimentación":** Se compara la gráfica con una montaña, donde las rocas se detienen en un punto, similar a la caída de la varianza explicada.
# - **Ejemplo práctico:** En el gráfico dado, **después del tercer componente** se observa un codo o área de sedimentación.
# - **Selección de componentes:** Se eligen **3 componentes principales**, que explican **83% de la varianza**.
# - **Disminución de la varianza explicada:** Después del tercer componente, cada nuevo componente explica **menos del 7%** de los datos.
# - **Limitación del método:** Este análisis visual es **ad hoc** y **no hay una regla objetiva universal** para determinar el número óptimo de componentes.

# %% [markdown]
# # Ejercicios en Clase
#
# En este ejercicio trabajaremos con una base de datos del Banco Mundial, que contiene indicadores económicos clave de países de América Latina y el Caribe a lo largo de los años.
#
#
# Objetivo del ejercicio:
#
# Aplicaremos Análisis de Componentes Principales (PCA) para entender qué factores explican mejor las diferencias económicas entre los países. Reduciremos la cantidad de variables sin perder información clave y exploraremos cómo se agrupan los países según sus características económicas.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MECA4605-Aprendizaje-no-supervisado/S1_clase_PCA/main/data/world_bank_indicators.csv')
df
# Out:
#               Country Name Country Code  Year  \
# 0      Antigua and Barbuda          ATG  2000
# 1      Antigua and Barbuda          ATG  2001
# 2      Antigua and Barbuda          ATG  2002
# 3      Antigua and Barbuda          ATG  2003
# 4      Antigua and Barbuda          ATG  2004
# ..                     ...          ...   ...
# 709  Virgin Islands (U.S.)          VIR  2019
# 710  Virgin Islands (U.S.)          VIR  2020
# 711  Virgin Islands (U.S.)          VIR  2021
# 712  Virgin Islands (U.S.)          VIR  2022
# 713  Virgin Islands (U.S.)          VIR  2023
#
#      Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                100.0
# 1                                                100.0
# 2                                                100.0
# 3                                                100.0
# 4                                                100.0
# ...

# %% [markdown]
# ### *Calcula estadísticas descriptivas y analiza la distribución de las variables.*

# %% [markdown]
# ### *¿Cuáles son las variables con mayor varianza? ¿Por qué es esto importante para PCA?*

# %% [markdown]
# ### *¿Existen valores faltantes? ¿Cómo los manejamos?*

# %% [markdown]
# ### *¿Cómo están correlacionadas las variables económicas?*

# %% [markdown]
# ### *¿Cómo afecta la estandarización a los datos?*

# %% [markdown]
# ### *¿Cuántos componentes principales se necesitan para explicar al menos el 90% de la varianza?*

# %% [markdown]
# ### *¿Cómo interpretar los primeros componentes principales?*

# %% [markdown]
# ### *¿Cómo se distribuyen los países en los primeros dos componentes?*
